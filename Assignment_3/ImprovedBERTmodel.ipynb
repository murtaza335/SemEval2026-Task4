# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/AIprojectSemEval
# Out:
# /content/drive/MyDrive/AIprojectSemEval

# %%
# %cd /content/drive/MyDrive/AIprojectSemEval
# !ls
# Out:
# /content/drive/MyDrive/AIprojectSemEval
# AI_Project_SemEval_Github_repo.zip

# %%
# !mkdir -p /content/AIprojectSemEval
# %cd /content/AIprojectSemEval
# !ls
# Out:
# /content/AIprojectSemEval

# %%
# !python /content/AIprojectSemEval/run_experiments.py
# Out:
# Device: cuda
# Train samples: 160, Validation samples: 40
# Train: 160 Val: 40
# Label counts (train): Counter({1: 86, 0: 74})
# 2025-12-11 23:35:20.172224: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765496120.209232   15933 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765496120.221023   15933 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765496120.246643   15933 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python run_experiments.py --data dev_track_a.jsonl --epochs 10 --batch_size 4
# Out:
# Device: cuda
# Train: 160 Val: 40
# Label counts (train): Counter({1: 81, 0: 79})
# 2025-12-12 00:56:56.054096: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765501016.076657   36853 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765501016.087201   36853 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765501016.113977   36853 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python evaluate_results.py --data dev_track_a.jsonl --model_path results/bert_proposed/best_model.pt --max_len 128 --prompt_len 25
# Out:
# 2025-12-12 01:04:03.551903: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765501443.574630   38683 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765501443.581683   38683 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765501443.598529   38683 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
